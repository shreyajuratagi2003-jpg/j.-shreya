# %%
# Expense Tracker System

## Overview
The Expense Tracker System is a menu-driven Python mini project designed to help users record, manage, and monitor daily expenses efficiently. The system allows users to add, view, search, and delete expense records while storing data permanently using file handling.

## Problem Statement
Tracking expenses manually can lead to incorrect calculations, loss of data, and difficulty in monitoring spending habits. This project provides a simple digital solution for effective expense management.

## Features
- Add new expense records
- View all expenses
- Search expenses by category
- Delete expense records
- Menu-driven user interface
- Permanent data storage using file handling

## Data Fields Used
- Expense ID
- Date
- Category
- Description
- Amount

## Python Concepts Used

### Data Structures
- Dictionary of Lists
- Lists for storing multiple expense records

### Libraries Used
- pandas
- numpy

### Control Structures
- while loop
- if / elif / else statements

### Functions Used
- view_expenses()
- add_expense()
- search_expense()
- delete_expense()
- save_to_file()

### Methods Used
- List methods: append(), pop(), len()
- Dictionary methods: keys(), values(), get()
- String methods: strip(), title()

### Exception Handling
- try / except blocks are used to handle invalid inputs such as entering text instead of numbers.

### File Handling
- Expense data is saved in a text file named expenses.txt
- with open() is used for reading and writing data safely

## How to Run
1. Open Jupyter Notebook
2. Open Expense_Tracker_System.ipynb
3. Run all cells
4. Follow the menu displayed on the screen

## Files Included
- Expense_Tracker_System.ipynb
- README.md
- expenses.txt

## Conclusion
The Expense Tracker System demonstrates the practical use of Python programming concepts to manage real-world financial data. The project is simple, efficient, and can be extended further.

## Author Details
Name: J.shreya
USN: 1BG24BA045 
Course: Python Programming
